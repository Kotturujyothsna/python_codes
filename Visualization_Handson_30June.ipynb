# %% [markdown]
# ## Visualization Handson:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('cars.csv', skipinitialspace=True)
df
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year    brand
# 0    14.0          8        350.0  165     4209.0          12  1972      US.
# 1    31.9          4         89.0   71     1925.0          14  1980  Europe.
# 2    17.0          8        302.0  140     3449.0          11  1971      US.
# 3    15.0          8        400.0  150     3761.0          10  1971      US.
# 4    30.5          4         98.0   63     2051.0          17  1978      US.
# ..    ...        ...          ...  ...        ...         ...   ...      ...
# 256  17.0          8        305.0  130     3840.0          15  1980      US.
# 257  36.1          4         91.0   60     1800.0          16  1979   Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983      US.
# 259  18.0          6        232.0  100     3288.0          16  1972      US.
# 260  22.0          6        250.0  105     3353.0          15  1977      US.
#
# [261 rows x 8 columns]

# %%
df.dtypes
# Out:
# mpg            float64
# cylinders        int64
# cubicinches    float64
# hp               int64
# weightlbs      float64
# time-to-60       int64
# year             int64
# brand           object
# dtype: object

# %%
df['brand'].unique()
# Out:
# array(['US.', 'Europe.', 'Japan.'], dtype=object)

# %%
df['brand'].value_counts()
# Out:
# US.        162
# Japan.      51
# Europe.     48
# Name: brand, dtype: int64

# %%
df.isnull().sum() # OR df.isna().sum()
# Out:
# mpg            0
# cylinders      0
# cubicinches    2
# hp             0
# weightlbs      3
# time-to-60     0
# year           0
# brand          0
# dtype: int64

# %%
df[df['brand'] == 'Japan.']
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year   brand
# 9    37.7          4         89.0   62     2050.0          17  1982  Japan.
# 10   34.0          4        108.0   70     2245.0          17  1983  Japan.
# 16   31.8          4         85.0   65     2020.0          19  1980  Japan.
# 18   24.0          4        113.0   95     2278.0          16  1973  Japan.
# 20   37.2          4         86.0   65     2019.0          16  1981  Japan.
# 24   38.1          4         89.0   60     1968.0          19  1981  Japan.
# 25   33.0          4         91.0   53     1795.0          17  1977  Japan.
# 26   31.0          4         71.0   65     1773.0          19  1972  Japan.
# 30   27.0          4         97.0   88     2130.0          15  1971  Japan.
# 32   23.0          4        120.0   97     2506.0          15  1973  Japan.
# 34   30.0          4         97.0   67     1985.0          16  1978  Japan.
# ...

# %%
# Top 10 rows
df.head(10)
# Out:
#     mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year    brand
# 0  14.0          8        350.0  165     4209.0          12  1972      US.
# 1  31.9          4         89.0   71     1925.0          14  1980  Europe.
# 2  17.0          8        302.0  140     3449.0          11  1971      US.
# 3  15.0          8        400.0  150     3761.0          10  1971      US.
# 4  30.5          4         98.0   63     2051.0          17  1978      US.
# 5  23.0          8        350.0  125     3900.0          17  1980      US.
# 6  13.0          8        351.0  158     4363.0          13  1974      US.
# 7  14.0          8        440.0  215     4312.0           9  1971      US.
# 8  25.4          5        183.0   77     3530.0          20  1980  Europe.
# 9  37.7          4         89.0   62     2050.0          17  1982   Japan.

# %%
# Bottom 5 rows
df.tail()
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year   brand
# 256  17.0          8        305.0  130     3840.0          15  1980     US.
# 257  36.1          4         91.0   60     1800.0          16  1979  Japan.
# 258  22.0          6        232.0  112     2835.0          15  1983     US.
# 259  18.0          6        232.0  100     3288.0          16  1972     US.
# 260  22.0          6        250.0  105     3353.0          15  1977     US.

# %%
# Shape of dataset
df.shape
# Out:
# (261, 8)

# %%
# Statistical Information
df.describe()
# Out:
#               mpg   cylinders  cubicinches          hp    weightlbs  \
# count  261.000000  261.000000   259.000000  261.000000   258.000000
# mean    23.144828    5.590038   200.918919  106.360153  3009.833333
# std      7.823570    1.733310   109.258305   40.499959   854.039019
# min     10.000000    3.000000    68.000000   46.000000  1613.000000
# 25%     16.900000    4.000000    99.500000   75.000000  2248.000000
# 50%     22.000000    6.000000   156.000000   95.000000  2867.500000
# 75%     28.800000    8.000000   303.000000  138.000000  3670.000000
# max     46.600000    8.000000   455.000000  230.000000  4997.000000
#
#        time-to-60         year
# count  261.000000   261.000000
# mean    15.547893  1976.819923
# std      2.910625     3.637696
# min      8.000000  1971.000000
# 25%     14.000000  1974.000000
# 50%     16.000000  1977.000000
# 75%     17.000000  1980.000000
# max     25.000000  1983.000000

# %%
# Describe for Object datatype
df.describe(include='O')
# Out:
#        brand
# count    261
# unique     3
# top      US.
# freq     162

# %%
df['brand'].mode()
# Out:
# 0    US.
# Name: brand, dtype: object

# %% [markdown]
# #### Create scatter plots for the following data, make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.
#
# a. Create scatter plots with between (mpg-hp, mpg-weight), and (hp-mpg, hp-time-to-60) with respect to each brand.

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'cubicinches', 'hp', 'weightlbs', 'time-to-60',
#        'year', 'brand'],
#       dtype='object')

# %%
fig = plt.subplots(2, 2, figsize=(20, 10))

plt.subplot(2, 2, 1)
sns.scatterplot(x='mpg', y='hp', hue='brand', data=df)
plt.xlabel('Miles per gallon')
plt.ylabel('Horsepower')
plt.title('MPG vs HP')

plt.subplot(2, 2, 2)
sns.scatterplot(x='mpg', y='weightlbs', hue='brand', data=df)
plt.xlabel('Miles per gallon')
plt.ylabel('Weight')
plt.title('MPG vs Weightlbs')

plt.subplot(2, 2, 3)
sns.scatterplot(x='hp', y='mpg', hue='brand', data=df)
plt.xlabel('Horsepower')
plt.ylabel('Miles per gallon')
plt.title('HP vs MPG')

plt.subplot(2, 2, 4)
sns.scatterplot(x='hp', y='time-to-60', hue='brand', data=df)
plt.xlabel('Horsepower')
plt.ylabel('Time to 60')
plt.title('HP vs Time-to-60')

plt.tight_layout() # To evenly space plots
plt.show()

# %% [markdown]
# #### Create bar plots for the following, make sure all the plots appear in the same plane with x-labels and y-labels evenly spaced.
#
# a. Create a bar plot that shows the visual representation of hp, mpg, weight, time-to-60 with respect to the number of cylinders for each of the brands.
#
# - Take cylinders as x, brand as hue.

# %%
fig = plt.subplots(2, 2, figsize=(20, 10))

plt.subplot(2, 2, 1)
sns.barplot(x='cylinders', y='hp', hue='brand', data=df)
plt.xlabel('Cylinders')
plt.ylabel('Horsepower')
plt.title('Cylinders vs HP')

plt.subplot(2, 2, 2)
sns.barplot(x='cylinders', y='mpg', hue='brand', data=df)
plt.xlabel('Cylinders')
plt.ylabel('Miles Per gallon')
plt.title('Cylinders vs MPG')

plt.subplot(2, 2, 3)
sns.barplot(x='cylinders', y='weightlbs', hue='brand', data=df)
plt.xlabel('Cylinders')
plt.ylabel('Weight')
plt.title('Cylinders vs Weightlbs')

plt.subplot(2, 2, 4)
sns.barplot(x='cylinders', y='time-to-60', hue='brand', data=df)
plt.xlabel('Cylinders')
plt.ylabel('Time-to-60')
plt.title('Cylinders vs Time-to-60')

plt.tight_layout()
plt.show()

# %%
df[df['cylinders'] == 3]
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year   brand
# 37   21.5          3         80.0  110     2720.0          14  1978  Japan.
# 156  18.0          3         70.0   90     2124.0          14  1974  Japan.

# %%
df[df['cylinders'] == 5]
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year    brand
# 8    25.4          5        183.0   77     3530.0          20  1980  Europe.
# 171  20.3          5        131.0  103     2830.0          16  1979  Europe.
# 252  36.4          5        121.0   67     2950.0          20  1981  Europe.

# %%
df[df['cylinders'] == 8]
# Out:
#       mpg  cylinders  cubicinches   hp  weightlbs  time-to-60  year brand
# 0    14.0          8        350.0  165     4209.0          12  1972   US.
# 2    17.0          8        302.0  140     3449.0          11  1971   US.
# 3    15.0          8        400.0  150     3761.0          10  1971   US.
# 5    23.0          8        350.0  125     3900.0          17  1980   US.
# 6    13.0          8        351.0  158     4363.0          13  1974   US.
# ..    ...        ...          ...  ...        ...         ...   ...   ...
# 244  14.0          8        454.0  220     4354.0           9  1971   US.
# 245  15.0          8        318.0  150     3399.0          11  1974   US.
# 246  19.4          8        318.0  140     3735.0          13  1979   US.
# 253  13.0          8        350.0  145     3988.0          13  1974   US.
# 256  17.0          8        305.0  130     3840.0          15  1980   US.
#
# [76 rows x 8 columns]

# %% [markdown]
# #### Create a heatmap for the entire data to study correlation between each of the columns.

# %%
df.corr(numeric_only=True)
# Out:
#                   mpg  cylinders  cubicinches        hp  weightlbs  \
# mpg          1.000000  -0.776710    -0.803964 -0.774905  -0.825234
# cylinders   -0.776710   1.000000     0.951452  0.845155   0.896093
# cubicinches -0.803964   0.951452     1.000000  0.906902   0.930027
# hp          -0.774905   0.845155     0.906902  1.000000   0.861028
# weightlbs   -0.825234   0.896093     0.930027  0.861028   1.000000
# time-to-60   0.509070  -0.578161    -0.613199 -0.744873  -0.480772
# year         0.550441  -0.322239    -0.350293 -0.383869  -0.281119
#
#              time-to-60      year
# mpg            0.509070  0.550441
# cylinders     -0.578161 -0.322239
# cubicinches   -0.613199 -0.350293
# hp            -0.744873 -0.383869
# weightlbs     -0.480772 -0.281119
# time-to-60     1.000000  0.312311
# year           0.312311  1.000000

# %%
sns.heatmap(df.corr(numeric_only=True))
plt.show()

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues') # Or cmap='Greens' or 'coolwarm'
plt.show()

# %% [markdown]
# #### Create line plots for the following:
#
# a. Line plot between hp-mpg, hp-(time-to-60), mpg-(time-to-60), hp-weight lbs, mpg-weight lbs, cubic inches-weight lbs with respect to brand.

# %%
fig = plt.subplots(3, 2, figsize=(20, 10))

plt.subplot(3, 2, 1)
sns.lineplot(x='hp', y='mpg', hue='brand', errorbar=None, data=df)

plt.subplot(3, 2, 2)
sns.lineplot(x='hp', y='time-to-60', hue='brand', errorbar=None, data=df)

plt.subplot(3, 2, 3)
sns.lineplot(x='mpg', y='time-to-60', hue='brand', data=df)

plt.subplot(3, 2, 4)
sns.lineplot(x='hp', y='weightlbs', hue='brand', data=df)

plt.subplot(3, 2, 5)
sns.lineplot(x='mpg', y='weightlbs', hue='brand', data=df)

plt.subplot(3, 2, 6)
sns.lineplot(x='cubicinches', y='weightlbs', hue='brand', data=df)

plt.show()

# %% [markdown]
# #### Create a pie chart for the following columns and their distribution in the data:
#
# a. Brands

# %%
x = df['brand'].value_counts()
x
# Out:
# US.        162
# Japan.      51
# Europe.     48
# Name: brand, dtype: int64

# %%
162 + 51 + 48 # Total number of rows
# Out:
# 261

# %%
df.shape
# Out:
# (261, 8)

# %%
(162/261) * 100 # Percentage of US cars
# Out:
# 62.06896551724138

# %%
(51/261) * 100 # Percentage of Japanese cars
# Out:
# 19.54022988505747

# %%
(48/261) * 100 # Percentage of European cars
# Out:
# 18.39080459770115

# %%
plt.pie(x, labels=x.index, autopct='%.2f', explode=[0.1, 0.1, 0.1], shadow=True)
plt.title('Cars distribution by country')
plt.show()

# %% [markdown]
# #### Create violin plots for the following:
#
# a. hp, mpg, time-to-60, with respect to the number of cylinders for each brand.

# %%
fig = plt.subplots(1, 3, figsize=(20, 10))

plt.subplot(1, 3, 1)
sns.violinplot(x='hp', hue='cylinders', data=df)

plt.subplot(1, 3, 2)
sns.violinplot(x='mpg', hue='cylinders', data=df)

plt.subplot(1, 3, 3)
sns.violinplot(x='time-to-60', hue='cylinders', data=df)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Create a histogram for the following:
#
# a. Create histograms for hp, mpg, time-to-60, weight lbs, cubic inches, year, with respect to brand.

# %%
# Try
